# %%
#--------------hypothesis-test------------
# Close Price - VWAP
# Buy Reco – More than 60
# Upside > 0 
# PE Ratio – 0 and above
# % Upside -5.00 and above

1."create buy/sell column in dataset"
2."select predictor column  (close price,profit ,etc )"
3."contingency table"
4." perform chi-square test on decision vs target column"

# %%
#example

import pandas as pd
data = pd.read_csv("./50_Startups.csv")
ct=pd.crosstab(data['Profit'],data['State'])
ct
# Out:
# State      California  Florida  New York
# Profit
# 14681.40            1        0         0
# 35673.41            0        0         1
# 42559.73            1        0         0
# 49490.75            0        1         0
# 64926.08            0        0         1
# 65200.33            1        0         0
# 69758.98            0        0         1
# 71498.49            1        0         0
# 77798.83            0        1         0
# 78239.91            1        0         0
# 81005.76            1        0         0
# 81229.06            0        0         1
# 89949.14            1        0         0
# 90708.19            0        1         0
# 96479.51            0        0         1
# 96712.80            1        0         0
# 96778.92            0        1         0
# 97427.84            1        0         0
# 97483.56            0        0         1
# 99937.59            0        1         0
# 101004.64           0        0         1
# 103282.38           0        1         0
# ...

# %%
from scipy.stats import chi2_contingency
stat,pvalue,_,expected_R= chi2_contingency(ct)

if pvalue <= 0.05:
    print("Conditions performing well")
else:
    print("Change the conditions")
# Out:
# Change the conditions

# %%
expected_R.shape
stat
# Out:
# 99.99999999999999

# %%
pvalue
# Out:
# 0.42486667820276625
